# %%
import pandas as pd
import json
import re
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
run_name = "cictt_registry"

# load JSONL
records = []
with open("../aircraft_er_predictions/" + run_name + "_predictions_all.tsv") as f:
    for line in f:
        records.append(json.loads(line))


        # load JSONL
records_test = []
with open("../aircraft_er_predictions/" + run_name + "_predictions_test.tsv") as f:
    for line in f:
        records_test.append(json.loads(line))

# %%
df_all = pd.DataFrame(records)
df_test = pd.DataFrame(records_test)
df_test.head()
# Out:
#                                                 left  \
# 0  COL make VAL DE HAVILLAND COL model VAL DH104 ...
# 1  COL make VAL BEECH COL model VAL C45 COL serie...
# 2  COL make VAL DOUGLAS COL model VAL C54 COL ser...
# 3  COL make VAL BELL COL model VAL 47G COL series...
# 4  COL make VAL STEARMAN COL model VAL 4 COL seri...
#
#                                                right  match  match_confidence
# 0  COL make VAL DEHAVILLAND COL model VAL DH104 D...      0          0.999891
# 1              COL make VAL BEECH COL model VAL C-45      0          0.999620
# 2            COL make VAL DOUGLAS COL model VAL C-54      1          0.999678
# 3  COL make VAL VALENTIN GMBH COL model VAL TAIFU...      0          0.999960
# 4    COL make VAL STEARMAN AIRCRAFT COL model VAL 4D      1          0.999454

# %%
gold_test = pd.read_csv("../data/ditto_aircraft/" + run_name + "/test.txt", sep="\t", header=None, names=["left", "right", "gold"])

gold_all = pd.read_csv("../data/ditto_aircraft/" + run_name + "/all_pairs.txt", sep="\t", header=None, names=["left", "right", "gold"])
print(gold_all.head())
# Out:
#                                                 left  \
# 0  COL make VAL FOKKER COL model VAL F27 COL seri...
# 1  COL make VAL CESSNA COL model VAL 206 COL seri...
# 2  COL make VAL FAIRCHILD COL model VAL 24 COL se...
# 3  COL make VAL CESSNA COL model VAL 414 COL seri...
# 4  COL make VAL BEECH COL model VAL 24 COL series...
#
#                                         right  gold
# 0  COL make VAL FOKKER COL model VAL F.27-400     0
# 1      COL make VAL PIPER COL model VAL PA-22     0
# 2   COL make VAL FAIRCHILD COL model VAL 24 J     0
# 3       COL make VAL CESSNA COL model VAL 414     0
# 4     COL make VAL BEECH COL model VAL A23-24     0

# %%
df_all["gold"] = gold_all["gold"]
df_test["gold"] = gold_test["gold"]

# %%
#Test Data

y_true_test = df_test["gold"]
y_pred_test = df_test["match"]

print("Accuracy:", accuracy_score(y_true_test, y_pred_test))
print("\nClassification report:\n", classification_report(y_true_test, y_pred_test))
print("\nConfusion matrix:\n", confusion_matrix(y_true_test, y_pred_test))



with open("../aircraft_er_predictions/" + run_name + "_metrics_test.txt", "w") as f:
    print("Accuracy:", accuracy_score(y_true_test, y_pred_test), file=f)
    print("\nClassification report:\n", file=f)
    print(classification_report(y_true_test, y_pred_test), file=f)
    print("\nConfusion matrix:\n", file=f)
    print(confusion_matrix(y_true_test, y_pred_test), file=f)
# Out:
# Accuracy: 0.9827709978463748
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2474
#            1       0.96      0.89      0.92       312
#
#     accuracy                           0.98      2786
#    macro avg       0.97      0.94      0.96      2786
# weighted avg       0.98      0.98      0.98      2786
#
#
# Confusion matrix:
#  [[2461   13]
#  [  35  277]]

# %%
#All Data

y_true = df_all["gold"]
y_pred = df_all["match"]

print("Accuracy:", accuracy_score(y_true, y_pred))
print("\nClassification report:\n", classification_report(y_true, y_pred))
print("\nConfusion matrix:\n", confusion_matrix(y_true, y_pred))



with open("../aircraft_er_predictions/" + run_name + "_metrics_all.txt", "w") as f:
    print("Accuracy:", accuracy_score(y_true, y_pred), file=f)
    print("\nClassification report:\n", file=f)
    print(classification_report(y_true, y_pred), file=f)
    print("\nConfusion matrix:\n", file=f)
    print(confusion_matrix(y_true, y_pred), file=f)
# Out:
# Accuracy: 0.9897876479170044
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     15498
#            1       0.99      0.95      0.97      3009
#
#     accuracy                           0.99     18507
#    macro avg       0.99      0.97      0.98     18507
# weighted avg       0.99      0.99      0.99     18507
#
#
# Confusion matrix:
#  [[15456    42]
#  [  147  2862]]

# %%
errors = df_test[df_test["gold"] != df_test["match"]]
print(errors[["left","right","gold","match","match_confidence"]].head(20))
# Out:
#                                                    left  \
# 23    COL make VAL AIRBUS HELICOPTERS COL model VAL ...
# 32    COL make VAL CASA COL model VAL CN235 COL seri...
# 112   COL make VAL BELL COL model VAL 206 COL series...
# 245   COL make VAL PIPER COL model VAL J4 COL series...
# 256   COL make VAL SIKORSKY COL model VAL HRS3 COL s...
# 258   COL make VAL BOEING COL model VAL 720 COL seri...
# 361   COL make VAL BELLANCA COL model VAL 17 31 COL ...
# 421   COL make VAL THORP COL model VAL T211 COL seri...
# 441   COL make VAL KAWASAKI COL model VAL BK117 COL ...
# 456   COL make VAL PIPER COL model VAL PA18 COL seri...
# 461   COL make VAL PILATUS COL model VAL PC6 COL ser...
# 605   COL make VAL BRITTEN NORMAN COL model VAL BN2A...
# 630   COL make VAL LOCKHEED COL model VAL R2O COL se...
# 856   COL make VAL AEROSPATIALE COL model VAL AS350 ...
# 905   COL make VAL AERONCA COL model VAL L16 COL ser...
# 961   COL make VAL AIRBUS HELICOPTERS COL model VAL ...
# 1108  COL make VAL MCDONNELL DOUGLAS COL model VAL M...
# 1159  COL make VAL BELL COL model VAL UH1 COL series...
# 1203  COL make VAL BEECH COL model VAL RU21 COL seri...
# 1265  COL make VAL BELL COL model VAL OH58 COL serie...
#
#                                                   right  gold  match  \
# 23    COL make VAL AIRBUS HELICOPTERS DEUTSCHLAND CO...     0      1
# 32    COL make VAL CONSTRUCCIONES AERONAUTICAS SA CO...     1      0
# 112              COL make VAL BELL COL model VAL 206B-I     1      0
# 245              COL make VAL PIPER COL model VAL J4A-S     1      0
# 256   COL make VAL SIKORSKY/CARSON SERVICES INC COL ...     1      0
# 258             COL make VAL BOEING COL model VAL 720-B     1      0
# 361         COL make VAL BELLANCA COL model VAL 17-31TC     1      0
# 421   COL make VAL THORP AIRCRAFT CO COL model VAL T...     1      0
# 441     COL make VAL MESSERSCHMITT COL model VAL BK 117     1      0
# 456         COL make VAL PIPER COL model VAL PA-18A 150     1      0
# 461        COL make VAL PILATUS COL model VAL PC-6/A-H2     0      1
# 605   COL make VAL BRITTEN NORMAN COL model VAL BN 2...     1      0
# 630            COL make VAL LOCKHEED COL model VAL R-20     1      0
# 856   COL make VAL AEROSPATIALE COL model VAL AS350B...     1      0
# 905   COL make VAL CHAMPION COL model VAL AERONCA L-16B     1      0
# 961   COL make VAL AIRBUS HELICOPTERS DEUTSCHLAND CO...     0      1
# 1108  COL make VAL MCDONNELL DOUGLAS COL model VAL D...     1      0
# 1159              COL make VAL BELL COL model VAL TH-1F     0      1
# 1203          COL make VAL BEECH COL model VAL 65-A90-1     1      0
# 1265             COL make VAL BELL COL model VAL OH-58A     0      1
#
#       match_confidence
# 23            0.526588
# 32            0.998065
# 112           0.992496
# 245           0.918344
# 256           0.999401
# 258           0.999846
# 361           0.999535
# 421           0.995085
# 441           0.773122
# 456           0.933280
# 461           0.964855
# 605           0.995338
# 630           0.692376
# 856           0.999396
# 905           0.999816
# 961           0.526588
# 1108          0.997147
# 1159          0.480986
# 1203          0.660710
# 1265          0.494226

# %%
errors
# Out:
#                                                    left  \
# 23    COL make VAL AIRBUS HELICOPTERS COL model VAL ...
# 32    COL make VAL CASA COL model VAL CN235 COL seri...
# 112   COL make VAL BELL COL model VAL 206 COL series...
# 245   COL make VAL PIPER COL model VAL J4 COL series...
# 256   COL make VAL SIKORSKY COL model VAL HRS3 COL s...
# 258   COL make VAL BOEING COL model VAL 720 COL seri...
# 361   COL make VAL BELLANCA COL model VAL 17 31 COL ...
# 421   COL make VAL THORP COL model VAL T211 COL seri...
# 441   COL make VAL KAWASAKI COL model VAL BK117 COL ...
# 456   COL make VAL PIPER COL model VAL PA18 COL seri...
# 461   COL make VAL PILATUS COL model VAL PC6 COL ser...
# 605   COL make VAL BRITTEN NORMAN COL model VAL BN2A...
# 630   COL make VAL LOCKHEED COL model VAL R2O COL se...
# 856   COL make VAL AEROSPATIALE COL model VAL AS350 ...
# 905   COL make VAL AERONCA COL model VAL L16 COL ser...
# 961   COL make VAL AIRBUS HELICOPTERS COL model VAL ...
# 1108  COL make VAL MCDONNELL DOUGLAS COL model VAL M...
# 1159  COL make VAL BELL COL model VAL UH1 COL series...
# 1203  COL make VAL BEECH COL model VAL RU21 COL seri...
# 1265  COL make VAL BELL COL model VAL OH58 COL serie...
# 1427  COL make VAL AEROSPATIALE COL model VAL AS350 ...
# 1482  COL make VAL BRITTEN NORMAN COL model VAL BN2A...
# 1546  COL make VAL BOEING COL model VAL 707 COL seri...
# 1602  COL make VAL BELL COL model VAL UH1 COL series...
# 1633  COL make VAL BELL COL model VAL 214 COL series...
# 1644  COL make VAL FAIRCHILD HILLER COL model VAL FH...
# 1702  COL make VAL BOEING COL model VAL 747 COL seri...
# 1706  COL make VAL BELL COL model VAL OH13 COL serie...
# 1741  COL make VAL WACO COL model VAL YQC COL series...
# 1808  COL make VAL AIRBUS HELICOPTERS COL model VAL ...
# 1835  COL make VAL AERO COMMANDER COL model VAL 680 ...
# 1837  COL make VAL BELL COL model VAL UH1 COL series...
# 1857  COL make VAL PILATUS COL model VAL PC6 COL ser...
# 1858  COL make VAL DE HAVILLAND COL model VAL DH114 ...
# 1860  COL make VAL SIKORSKY COL model VAL S58 COL se...
# 1943  COL make VAL PIPER COL model VAL PA46 COL seri...
# 2031  COL make VAL CESSNA COL model VAL R172 COL ser...
# 2113  COL make VAL AEROSPATIALE COL model VAL AS355 ...
# 2241  COL make VAL HUGHES COL model VAL 369 COL seri...
# 2297  COL make VAL PARTENAVIA COL model VAL AP68 COL...
# 2308  COL make VAL BELL COL model VAL OH13 COL serie...
# 2311  COL make VAL THORP COL model VAL T211 COL seri...
# 2352  COL make VAL TAYLORCRAFT COL model VAL BL12 CO...
# 2492  COL make VAL NORTH AMERICAN COL model VAL BC1 ...
# 2524  COL make VAL DOUGLAS COL model VAL DC3C COL se...
# 2534  COL make VAL FOKKER COL model VAL F28 COL seri...
# 2545  COL make VAL BEECH COL model VAL T42 COL serie...
# 2746  COL make VAL BOEING COL model VAL 707 COL seri...
#
#                                                   right  match  \
# 23    COL make VAL AIRBUS HELICOPTERS DEUTSCHLAND CO...      1
# 32    COL make VAL CONSTRUCCIONES AERONAUTICAS SA CO...      0
# 112              COL make VAL BELL COL model VAL 206B-I      0
# 245              COL make VAL PIPER COL model VAL J4A-S      0
# 256   COL make VAL SIKORSKY/CARSON SERVICES INC COL ...      0
# 258             COL make VAL BOEING COL model VAL 720-B      0
# 361         COL make VAL BELLANCA COL model VAL 17-31TC      0
# 421   COL make VAL THORP AIRCRAFT CO COL model VAL T...      0
# 441     COL make VAL MESSERSCHMITT COL model VAL BK 117      0
# 456         COL make VAL PIPER COL model VAL PA-18A 150      0
# 461        COL make VAL PILATUS COL model VAL PC-6/A-H2      1
# 605   COL make VAL BRITTEN NORMAN COL model VAL BN 2...      0
# 630            COL make VAL LOCKHEED COL model VAL R-20      0
# 856   COL make VAL AEROSPATIALE COL model VAL AS350B...      0
# 905   COL make VAL CHAMPION COL model VAL AERONCA L-16B      0
# 961   COL make VAL AIRBUS HELICOPTERS DEUTSCHLAND CO...      1
# 1108  COL make VAL MCDONNELL DOUGLAS COL model VAL D...      0
# 1159              COL make VAL BELL COL model VAL TH-1F      1
# 1203          COL make VAL BEECH COL model VAL 65-A90-1      0
# 1265             COL make VAL BELL COL model VAL OH-58A      1
# 1427  COL make VAL AEROSPATIALE COL model VAL AS350B...      0
# 1482  COL make VAL BRITTEN-NORMAN COL model VAL BN-2...      1
# 1546         COL make VAL BOEING COL model VAL 707-366C      0
# 1602  COL make VAL PRECISION HELICOPTERS LLC COL mod...      1
# 1633              COL make VAL BELL COL model VAL 214ST      0
# 1644         COL make VAL FAIRCHILD COL model VAL F-27B      0
# 1702         COL make VAL BOEING COL model VAL 747 212B      0
# 1706  COL make VAL TEXAS HELICOPTER CORP COL model V...      1
# 1741              COL make VAL WACO COL model VAL YPF-6      0
# 1808  COL make VAL AIRBUS HELICOPTERS DEUTSCHLAND CO...      1
# 1835    COL make VAL AERO COMMANDER COL model VAL 680FL      1
# 1837  COL make VAL PRECISION HELICOPTERS LLC COL mod...      1
# 1857       COL make VAL PILATUS COL model VAL PC-6/A-H2      1
# 1858  COL make VAL DEHAVILLAND COL model VAL DH-114 ...      0
# 1860         COL make VAL SIKORSKY COL model VAL S-58HT      0
# 1943        COL make VAL PIPER COL model VAL PA46-500TP      0
# 2031             COL make VAL CESSNA COL model VAL 172J      0
# 2113  COL make VAL EUROCOPTER/FRANCE COL model VAL A...      0
# 2241            COL make VAL HUGHES COL model VAL OH-6A      0
# 2297  COL make VAL PARTENAVIA C.A. S.P.A. COL model ...      0
# 2308  COL make VAL TEXAS HELICOPTER CORP COL model V...      1
# 2311  COL make VAL YOCUM PAUL E COL model VAL THORP ...      0
# 2352    COL make VAL TAYLORCRAFT COL model VAL BFS12-65      0
# 2492     COL make VAL NORTH AMERICAN COL model VAL BC1A      0
# 2524      COL make VAL DOUGLAS COL model VAL DC3C-S4C4G      0
# 2534      COL make VAL FOKKER COL model VAL F.28 MK4000      0
# 2545     COL make VAL BEECH COL model VAL 95-B55 (T42A)      0
# 2746         COL make VAL BOEING COL model VAL 707-358B      0
#
#       match_confidence  gold
# 23            0.526588     0
# 32            0.998065     1
# 112           0.992496     1
# 245           0.918344     1
# 256           0.999401     1
# 258           0.999846     1
# 361           0.999535     1
# 421           0.995085     1
# 441           0.773122     1
# 456           0.933280     1
# 461           0.964855     0
# 605           0.995338     1
# 630           0.692376     1
# 856           0.999396     1
# 905           0.999816     1
# 961           0.526588     0
# 1108          0.997147     1
# 1159          0.480986     0
# 1203          0.660710     1
# 1265          0.494226     0
# 1427          0.999394     1
# 1482          0.972320     0
# 1546          0.999903     1
# 1602          0.520994     0
# 1633          0.989790     1
# 1644          0.999413     1
# 1702          0.999352     1
# 1706          0.567957     0
# 1741          0.993340     1
# 1808          0.525350     0
# 1835          0.997732     0
# 1837          0.520994     0
# 1857          0.970136     0
# 1858          0.759855     1
# 1860          0.999838     1
# 1943          0.999639     1
# 2031          0.999772     1
# 2113          0.777676     1
# 2241          0.991803     1
# 2297          0.999532     1
# 2308          0.567957     0
# 2311          0.997382     1
# 2352          0.998618     1
# 2492          0.999488     1
# 2524          0.998792     1
# 2534          0.998291     1
# 2545          0.626608     1
# 2746          0.999891     1

# %%
errors.to_csv("../aircraft_er_predictions/" + run_name + "_errors_review.csv", index=False)

# %%
def parse_record(record: str):
    """Parse Ditto serialized record into a dict of {field: value}."""
    parts = re.split(r"COL |VAL ", record.strip())
    parts = [p for p in parts if p]  # drop empties
    return {parts[i].strip(): parts[i+1].strip() for i in range(0, len(parts), 2)}

parsed = []

for _, row in errors.iterrows():
    left = parse_record(row["left"])
    right = parse_record(row["right"])
    parsed.append({
        "cictt_make": left.get("make"),
        "make": right.get("make"),
        "cictt_model": left.get("model"),
        "model": right.get("model"),
        "cictt_series": left.get("series"),
        "series": right.get("series"),
        "cictt_cert": left.get("cert"),
        "cert": right.get("cert"),
        "cictt_name": left.get("name"),
        "name": right.get("name"),
        "gold": row["gold"],
        "predicted": row["match"],
        "confidence": row["match_confidence"]
    })

aligned = pd.DataFrame(parsed)

# %%
aligned.to_csv("../aircraft_er_predictions/" + run_name + "_aligned_errors_review.csv", index=False)
