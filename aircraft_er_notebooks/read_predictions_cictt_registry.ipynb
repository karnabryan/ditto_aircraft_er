# %%
import pandas as pd
import json
import re
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
run_name = "cictt_registry"

# load JSONL
records = []
with open("../aircraft_er_predictions/" + run_name + "_predictions_all.tsv") as f:
    for line in f:
        records.append(json.loads(line))


        # load JSONL
records_test = []
with open("../aircraft_er_predictions/" + run_name + "_predictions_test.tsv") as f:
    for line in f:
        records_test.append(json.loads(line))

# %%
df_all = pd.DataFrame(records)
df_test = pd.DataFrame(records_test)
df_test.head()
# Out:
#                                                 left  \
# 0  COL make VAL CESSNA COL model VAL 210 COL seri...
# 1  COL make VAL CHAMPION COL model VAL 7KC COL se...
# 2  COL make VAL FUJI COL model VAL FA200 COL seri...
# 3  COL make VAL BOEING COL model VAL 747 COL seri...
# 4  COL make VAL LOCKHEED COL model VAL 382 COL se...
#
#                                         right  match  match_confidence
# 0      COL make VAL CESSNA COL model VAL 210J      0          0.999641
# 1     COL make VAL CHAMPION COL model VAL 7KC      0          0.641302
# 2   COL make VAL BOEING COL model VAL 737-823      0          0.999926
# 3  COL make VAL BOEING COL model VAL 747-236F      1          0.999875
# 4    COL make VAL LOCKHEED COL model VAL 382E      1          0.999646

# %%
gold_test = pd.read_csv("../data/aircraft_er/" + run_name + "/test.txt", sep="\t", header=None, names=["left", "right", "gold"])

gold_all = pd.read_csv("../data/aircraft_er/" + run_name + "/all_pairs.txt", sep="\t", header=None, names=["left", "right", "gold"])
print(gold_all.head())
# Out:
#                                                 left  \
# 0  COL make VAL PIPER COL model VAL L21 COL serie...
# 1  COL make VAL BOEING COL model VAL 737 COL seri...
# 2  COL make VAL SWEARINGEN COL model VAL SA227 CO...
# 3  COL make VAL WACO COL model VAL DSO COL series...
# 4  COL make VAL BELL COL model VAL UH1 COL series...
#
#                                                right  gold
# 0              COL make VAL PIPER COL model VAL L-21     0
# 1          COL make VAL BOEING COL model VAL 737-758     0
# 2  COL make VAL CONSTRUCCIONES AERONAUTICAS SA CO...     0
# 3           COL make VAL CESSNA COL model VAL TP206A     0
# 4              COL make VAL BELL COL model VAL UH-1F     1

# %%
df_all["gold"] = gold_all["gold"]
df_test["gold"] = gold_test["gold"]

# %%
#Test Data

y_true_test = df_test["gold"]
y_pred_test = df_test["match"]

print("Accuracy:", accuracy_score(y_true_test, y_pred_test))
print("\nClassification report:\n", classification_report(y_true_test, y_pred_test))
print("\nConfusion matrix:\n", confusion_matrix(y_true_test, y_pred_test))



with open("../aircraft_er_predictions/" + run_name + "_metrics_test.txt", "w") as f:
    print("Accuracy:", accuracy_score(y_true_test, y_pred_test), file=f)
    print("\nClassification report:\n", file=f)
    print(classification_report(y_true_test, y_pred_test), file=f)
    print("\nConfusion matrix:\n", file=f)
    print(confusion_matrix(y_true_test, y_pred_test), file=f)
# Out:
# Accuracy: 0.9685393258426966
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      1023
#            1       0.95      0.92      0.93       312
#
#     accuracy                           0.97      1335
#    macro avg       0.96      0.95      0.96      1335
# weighted avg       0.97      0.97      0.97      1335
#
#
# Confusion matrix:
#  [[1007   16]
#  [  26  286]]

# %%
#All Data

y_true = df_all["gold"]
y_pred = df_all["match"]

print("Accuracy:", accuracy_score(y_true, y_pred))
print("\nClassification report:\n", classification_report(y_true, y_pred))
print("\nConfusion matrix:\n", confusion_matrix(y_true, y_pred))



with open("../aircraft_er_predictions/" + run_name + "_metrics_all.txt", "w") as f:
    print("Accuracy:", accuracy_score(y_true, y_pred), file=f)
    print("\nClassification report:\n", file=f)
    print(classification_report(y_true, y_pred), file=f)
    print("\nConfusion matrix:\n", file=f)
    print(confusion_matrix(y_true, y_pred), file=f)
# Out:
# Accuracy: 0.9872052182639237
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      8949
#            1       0.97      0.97      0.97      3009
#
#     accuracy                           0.99     11958
#    macro avg       0.98      0.98      0.98     11958
# weighted avg       0.99      0.99      0.99     11958
#
#
# Confusion matrix:
#  [[8872   77]
#  [  76 2933]]

# %%
errors = df_test[df_test["gold"] != df_test["match"]]
print(errors[["left","right","gold","match","match_confidence"]].head(20))
# Out:
#                                                   left  \
# 1    COL make VAL CHAMPION COL model VAL 7KC COL se...
# 97   COL make VAL BELL COL model VAL UH1 COL series...
# 137  COL make VAL VERTOL COL model VAL CH47 COL ser...
# 165  COL make VAL DASSAULT COL model VAL MYSTERE FA...
# 166  COL make VAL DASSAULT COL model VAL FALCON 200...
# 200  COL make VAL EMBRAER COL model VAL EMB145 COL ...
# 295  COL make VAL CESSNA COL model VAL 305 COL seri...
# 298  COL make VAL BELL COL model VAL OH58 COL serie...
# 302  COL make VAL AEROSPATIALE COL model VAL SA365 ...
# 329  COL make VAL CASA COL model VAL CN235 COL seri...
# 355  COL make VAL PIPER COL model VAL L21 COL serie...
# 363  COL make VAL BAC COL model VAL ONE ELEVEN COL ...
# 385  COL make VAL AEROSPATIALE COL model VAL SA365 ...
# 390  COL make VAL PARTENAVIA COL model VAL P68 COL ...
# 432  COL make VAL BELL COL model VAL UH1 COL series...
# 501  COL make VAL BOEING COL model VAL 727 COL seri...
# 533  COL make VAL CONVAIR COL model VAL 340 COL ser...
# 535  COL make VAL BELL COL model VAL 214 COL series...
# 544  COL make VAL BEECH COL model VAL 65 COL series...
# 556  COL make VAL AEROSPATIALE COL model VAL AS355 ...
#
#                                                  right  gold  match  \
# 1              COL make VAL CHAMPION COL model VAL 7KC     1      0
# 97   COL make VAL GARLICK HELICOPTERS INC COL model...     1      0
# 137  COL make VAL COLUMBIA HELICOPTERS INC COL mode...     0      1
# 165  COL make VAL DASSAULT AVIATION COL model VAL F...     1      0
# 166  COL make VAL DASSAULT AVIATION COL model VAL F...     0      1
# 200       COL make VAL EMBRAER COL model VAL EMB-145MP     1      0
# 295      COL make VAL CESSNA COL model VAL 305C (0-1E)     1      0
# 298            COL make VAL BELL COL model VAL OH-58A+     1      0
# 302  COL make VAL AEROSPATIALE COL model VAL SA-365...     0      1
# 329  COL make VAL CONSTRUCCIONES AERONAUTICAS SA CO...     1      0
# 355              COL make VAL PIPER COL model VAL L-21     1      0
# 363  COL make VAL BRITISH AIRCRAFT CORP COL model V...     1      0
# 385  COL make VAL AEROSPATIALE COL model VAL SA-365...     0      1
# 390          COL make VAL NORTHROP COL model VAL P-61B     0      1
# 432  COL make VAL S M & T AIRCRAFT COL model VAL UH-1B     0      1
# 501          COL make VAL BOEING COL model VAL 727-287     1      0
# 533          COL make VAL CONVAIR COL model VAL 340-31     1      0
# 535             COL make VAL BELL COL model VAL 214B-1     1      0
# 544               COL make VAL BEECH COL model VAL A65     0      1
# 556  COL make VAL EUROCOPTER/FRANCE COL model VAL A...     1      0
#
#      match_confidence
# 1            0.641302
# 97           0.876477
# 137          0.724164
# 165          0.997728
# 166          0.999719
# 200          0.816454
# 295          0.642083
# 298          0.984476
# 302          0.883848
# 329          0.517801
# 355          0.997427
# 363          0.709904
# 385          0.883848
# 390          0.903180
# 432          0.817513
# 501          0.999576
# 533          0.999546
# 535          0.985970
# 544          0.951716
# 556          0.949215

# %%
errors
# Out:
#                                                    left  \
# 1     COL make VAL CHAMPION COL model VAL 7KC COL se...
# 97    COL make VAL BELL COL model VAL UH1 COL series...
# 137   COL make VAL VERTOL COL model VAL CH47 COL ser...
# 165   COL make VAL DASSAULT COL model VAL MYSTERE FA...
# 166   COL make VAL DASSAULT COL model VAL FALCON 200...
# 200   COL make VAL EMBRAER COL model VAL EMB145 COL ...
# 295   COL make VAL CESSNA COL model VAL 305 COL seri...
# 298   COL make VAL BELL COL model VAL OH58 COL serie...
# 302   COL make VAL AEROSPATIALE COL model VAL SA365 ...
# 329   COL make VAL CASA COL model VAL CN235 COL seri...
# 355   COL make VAL PIPER COL model VAL L21 COL serie...
# 363   COL make VAL BAC COL model VAL ONE ELEVEN COL ...
# 385   COL make VAL AEROSPATIALE COL model VAL SA365 ...
# 390   COL make VAL PARTENAVIA COL model VAL P68 COL ...
# 432   COL make VAL BELL COL model VAL UH1 COL series...
# 501   COL make VAL BOEING COL model VAL 727 COL seri...
# 533   COL make VAL CONVAIR COL model VAL 340 COL ser...
# 535   COL make VAL BELL COL model VAL 214 COL series...
# 544   COL make VAL BEECH COL model VAL 65 COL series...
# 556   COL make VAL AEROSPATIALE COL model VAL AS355 ...
# 570   COL make VAL BRANTLY COL model VAL B2 COL seri...
# 582   COL make VAL TAYLORCRAFT COL model VAL BC12 CO...
# 589   COL make VAL AEROSPATIALE COL model VAL AS350 ...
# 594   COL make VAL CHAMPION COL model VAL 7KC COL se...
# 621   COL make VAL BOEING COL model VAL 777 COL seri...
# 636   COL make VAL ANDERSON GREENWOOD COL model VAL ...
# 717   COL make VAL CHAMPION COL model VAL 7GCAA COL ...
# 723   COL make VAL DOUGLAS COL model VAL R4D COL ser...
# 766   COL make VAL PIPER COL model VAL PA60 COL seri...
# 815   COL make VAL MORANE SAULNIER COL model VAL MS7...
# 822   COL make VAL BEAGLE COL model VAL B206 COL ser...
# 925   COL make VAL SIKORSKY COL model VAL S58 COL se...
# 983   COL make VAL BOEING COL model VAL 747 COL seri...
# 1067  COL make VAL SIKORSKY COL model VAL S58 COL se...
# 1090  COL make VAL MORANE SAULNIER COL model VAL MS7...
# 1097  COL make VAL AIRBUS COL model VAL A319 COL ser...
# 1105  COL make VAL BAC COL model VAL ONE ELEVEN COL ...
# 1107  COL make VAL DOUGLAS COL model VAL DC3C COL se...
# 1216  COL make VAL PIPER COL model VAL PA46 COL seri...
# 1230  COL make VAL CALLAIR COL model VAL B1 COL seri...
# 1253  COL make VAL MBB COL model VAL BO105 COL serie...
# 1333  COL make VAL BEECH COL model VAL 55 COL series...
#
#                                                   right  match  \
# 1               COL make VAL CHAMPION COL model VAL 7KC      0
# 97    COL make VAL GARLICK HELICOPTERS INC COL model...      0
# 137   COL make VAL COLUMBIA HELICOPTERS INC COL mode...      1
# 165   COL make VAL DASSAULT AVIATION COL model VAL F...      0
# 166   COL make VAL DASSAULT AVIATION COL model VAL F...      1
# 200        COL make VAL EMBRAER COL model VAL EMB-145MP      0
# 295       COL make VAL CESSNA COL model VAL 305C (0-1E)      0
# 298             COL make VAL BELL COL model VAL OH-58A+      0
# 302   COL make VAL AEROSPATIALE COL model VAL SA-365...      1
# 329   COL make VAL CONSTRUCCIONES AERONAUTICAS SA CO...      0
# 355               COL make VAL PIPER COL model VAL L-21      0
# 363   COL make VAL BRITISH AIRCRAFT CORP COL model V...      0
# 385   COL make VAL AEROSPATIALE COL model VAL SA-365...      1
# 390           COL make VAL NORTHROP COL model VAL P-61B      1
# 432   COL make VAL S M & T AIRCRAFT COL model VAL UH-1B      1
# 501           COL make VAL BOEING COL model VAL 727-287      0
# 533           COL make VAL CONVAIR COL model VAL 340-31      0
# 535              COL make VAL BELL COL model VAL 214B-1      0
# 544                COL make VAL BEECH COL model VAL A65      1
# 556   COL make VAL EUROCOPTER/FRANCE COL model VAL A...      0
# 570             COL make VAL BRANTLY COL model VAL B-2A      0
# 582     COL make VAL TAYLORCRAFT COL model VAL BC12D-85      1
# 589      COL make VAL AEROSPATIALE COL model VAL AS350D      0
# 594             COL make VAL CHAMPION COL model VAL 7KC      0
# 621         COL make VAL BOEING COL model VAL 767-424ER      0
# 636   COL make VAL ANDERSON GREENWOOD COL model VAL ...      0
# 717           COL make VAL BELLANCA COL model VAL 7GCAA      0
# 723      COL make VAL DOUGLAS COL model VAL SUPER R4D-8      1
# 766       COL make VAL PIPER COL model VAL AEROSTAR 601      1
# 815   COL make VAL MORANE-SAULNIER COL model VAL MS7...      0
# 822    COL make VAL BEAGLE COL model VAL B.121 SERIES 1      1
# 925          COL make VAL SIKORSKY COL model VAL S-58HT      1
# 983          COL make VAL BOEING COL model VAL 747-268F      0
# 1067         COL make VAL SIKORSKY COL model VAL S-58DT      0
# 1090   COL make VAL MORANE-SAULNIER COL model VAL MS760      0
# 1097  COL make VAL AIRBUS INDUSTRIE COL model VAL A3...      1
# 1105  COL make VAL BRITISH AIRCRAFT CORP COL model V...      1
# 1107      COL make VAL DOUGLAS COL model VAL DC3C-S4C4G      0
# 1216             COL make VAL PIPER COL model VAL PA-30      1
# 1230  COL make VAL AERO COMMANDER COL model VAL CALL...      0
# 1253  COL make VAL MESSERSCHMITT BOLKOW BLOHM COL mo...      0
# 1333             COL make VAL BEECH COL model VAL 95-55      1
#
#       match_confidence  gold
# 1             0.641302     1
# 97            0.876477     1
# 137           0.724164     0
# 165           0.997728     1
# 166           0.999719     0
# 200           0.816454     1
# 295           0.642083     1
# 298           0.984476     1
# 302           0.883848     0
# 329           0.517801     1
# 355           0.997427     1
# 363           0.709904     1
# 385           0.883848     0
# 390           0.903180     0
# 432           0.817513     0
# 501           0.999576     1
# 533           0.999546     1
# 535           0.985970     1
# 544           0.951716     0
# 556           0.949215     1
# 570           0.965479     1
# 582           0.693833     0
# 589           0.997198     1
# 594           0.641302     1
# 621           0.999803     1
# 636           0.988986     1
# 717           0.636896     1
# 723           0.699200     0
# 766           0.999816     0
# 815           0.998622     1
# 822           0.999450     0
# 925           0.999841     0
# 983           0.999766     1
# 1067          0.808661     1
# 1090          0.989828     1
# 1097          0.878424     0
# 1105          0.671933     0
# 1107          0.911587     1
# 1216          0.586544     0
# 1230          0.998326     1
# 1253          0.772749     1
# 1333          0.994057     0

# %%
errors.to_csv("../aircraft_er_predictions/" + run_name + "_errors_review.csv", index=False)

# %%
def parse_record(record: str):
    """Parse Ditto serialized record into a dict of {field: value}."""
    parts = re.split(r"COL |VAL ", record.strip())
    parts = [p for p in parts if p]  # drop empties
    return {parts[i].strip(): parts[i+1].strip() for i in range(0, len(parts), 2)}

parsed = []

for _, row in errors.iterrows():
    left = parse_record(row["left"])
    right = parse_record(row["right"])
    parsed.append({
        "cictt_make": left.get("make"),
        "make": right.get("make"),
        "cictt_model": left.get("model"),
        "model": right.get("model"),
        "cictt_series": left.get("series"),
        "series": right.get("series"),
        "cictt_cert": left.get("cert"),
        "cert": right.get("cert"),
        "cictt_name": left.get("name"),
        "name": right.get("name"),
        "gold": row["gold"],
        "predicted": row["match"],
        "confidence": row["match_confidence"]
    })

aligned = pd.DataFrame(parsed)

# %%
left.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 left.head()
#
# AttributeError: 'dict' object has no attribute 'head'

# %%
aligned.to_csv("../aircraft_er_predictions/" + run_name + "_aligned_errors_review.csv", index=False)
