# %%
import pandas as pd
import json
import re

# %%
run_name = "make_model_union"


# load JSONL
records = []
with open("../aircraft_er_predictions/" + run_name + "_predictions_all.tsv") as f:
    for line in f:
        records.append(json.loads(line))

# %%
df = pd.DataFrame(records)
df.head()
# Out:
#                                                 left  \
# 0  COL make VAL EMBRAER COL model VAL EMB135 COL ...
# 1  COL make VAL SIKORSKY COL model VAL S55 COL na...
# 2  COL make VAL PIPER COL model VAL PA60 COL name...
# 3  COL make VAL CESSNA COL model VAL U3 COL cert ...
# 4  COL make VAL GRUMMAN COL model VAL HU16 COL na...
#
#                                                right  match  match_confidence
# 0          COL mfr VAL MITSUBISHI COL model VAL MU-2      0          0.999996
# 1  COL mfr VAL CESSNA COL model VAL 421 Executive...      0          0.999996
# 2  COL make VAL PIPER COL model VAL J2 COL series...      0          0.999996
# 3  COL mfr VAL CESSNA COL model VAL AT-8 Bobcat C...      0          0.999996
# 4  COL mfr VAL SNOW COL model VAL S-2 COL code VA...      0          0.999996

# %%
gold = pd.read_csv("../data/ditto_aircraft/" + run_name + "/all_pairs_with_id.txt")
print(gold.head())
# Out:
#           left_id                     right_id  \
# 0  EMBRAER EMB135                     MU2 MU-2
# 1    SIKORSKY S55  C421 421 Executive Commuter
# 2      PIPER PA60                         7448
# 3       CESSNA U3              T50 AT-8 Bobcat
# 4    GRUMMAN HU16                     SS2P S-2
#
#                                                 left  \
# 0  COL make VAL EMBRAER COL model VAL EMB135 COL ...
# 1  COL make VAL SIKORSKY COL model VAL S55 COL na...
# 2  COL make VAL PIPER COL model VAL PA60 COL name...
# 3  COL make VAL CESSNA COL model VAL U3 COL cert ...
# 4  COL make VAL GRUMMAN COL model VAL HU16 COL na...
#
#                                                right  label  \
# 0          COL mfr VAL MITSUBISHI COL model VAL MU-2      0
# 1  COL mfr VAL CESSNA COL model VAL 421 Executive...      0
# 2  COL make VAL PIPER COL model VAL J2 COL series...      0
# 3  COL mfr VAL CESSNA COL model VAL AT-8 Bobcat C...      0
# 4  COL mfr VAL SNOW COL model VAL S-2 COL code VA...      0
#
#                 source
# 0  doc8643_description
# 1  doc8643_description
# 2                cictt
# 3  doc8643_description
# 4  doc8643_description

# %%
df["gold"] = gold["label"]
df["left_id"] = gold["left_id"]
df["right_id"] = gold["right_id"]
df["source"] = gold["source"]

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

y_true = df["gold"]
y_pred = df["match"]

print("Accuracy:", accuracy_score(y_true, y_pred))
print("\nClassification report:\n", classification_report(y_true, y_pred))
print("\nConfusion matrix:\n", confusion_matrix(y_true, y_pred))
# Out:
# Accuracy: 0.9987870039375137
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    236021
#            1       0.99      0.99      0.99     28613
#
#     accuracy                           1.00    264634
#    macro avg       1.00      1.00      1.00    264634
# weighted avg       1.00      1.00      1.00    264634
#
#
# Confusion matrix:
#  [[235875    146]
#  [   175  28438]]

# %%
errors = df[(df["gold"] != df["match"])]
errors
# Out:
#                                                      left  \
# 6384    COL make VAL GULFSTREAM COL model VAL GV COL c...
# 9587    COL make VAL CHAMPION COL model VAL 7KC COL na...
# 13453   COL make VAL MONOCOUPE COL model VAL 90AL COL ...
# 13811   COL make VAL WACO COL model VAL INF COL cert V...
# 17328   COL make VAL DIAMOND COL model VAL DV20 COL na...
# ...                                                   ...
# 264020  COL make VAL TAYLORCRAFT COL model VAL BCS12 C...
# 264181  COL make VAL EUROCOPTER COL model VAL EC155 CO...
# 264183  COL make VAL WACO COL model VAL INF COL cert V...
# 264338  COL make VAL CONVAIR COL model VAL 440 COL nam...
# 264412  COL make VAL STEARMAN COL model VAL A75 COL na...
#
#                                                     right  match  \
# 6384    COL mfr VAL GULFSTREAM AEROSPACE COL model VAL...      0
# 9587             COL mfr VAL CHAMPION COL model VAL 7GCAA      1
# 13453              COL mfr VAL MONOCOUPE COL model VAL 90      1
# 13811                  COL mfr VAL WACO COL model VAL KNF      1
# 17328   COL mfr VAL DIAMOND COL model VAL DA-40 Katana...      1
# ...                                                   ...    ...
# 264020  COL make VAL TCRAFK COL model VAL BL COL serie...      1
# 264181      COL mfr VAL KOREA AEROSPACE COL model VAL LAH      0
# 264183                 COL mfr VAL WACO COL model VAL QCF      0
# 264338              COL mfr VAL CONVAIR COL model VAL 340      0
# 264412  COL make VAL B COL model VAL 75 COL series VAL...      0
#
#         match_confidence  gold            left_id           right_id  \
# 6384            0.706868     1      GULFSTREAM GV              GV-SP
# 9587            0.473192     0       CHAMPION 7KC       CHAMP-7-GCAA
# 13453           0.432130     0     MONOCOUPE 90AL          MONOCP-90
# 13811           0.458653     0           WACO INF       WACO-KNF-KNF
# 17328           0.999876     0       DIAMOND DV20  DA40 DA-40 Katana
# ...                  ...   ...                ...                ...
# 264020          0.530035     0  TAYLORCRAFT BCS12    TCRAFK-BL-S1265
# 264181          0.999996     1   EUROCOPTER EC155           EC55 LAH
# 264183          0.987778     1           WACO INF           WACF QCF
# 264338          0.999995     1        CONVAIR 440     CV-440-5800STC
# 264412          0.999996     1       STEARMAN A75          B-75-N2S4
#
#                      source
# 6384                    reg
# 9587                    reg
# 13453                   reg
# 13811                   reg
# 17328   doc8643_description
# ...                     ...
# 264020                  faa
# 264181  doc8643_description
# 264183  doc8643_description
# 264338                  reg
# 264412                  faa
#
# [321 rows x 8 columns]

# %%
errors.to_csv('cictt_agg_repeat_errors.csv', index=False)

# %%
matches = df[(df["gold"] == 1) & (df["match"] == 1)]
matches
# Out:
#                                                      left  \
# 11      COL make VAL AGUSTA COL model VAL AW119 COL na...
# 16      COL make VAL PARTENAVIA COL model VAL AP68 COL...
# 32      COL make VAL LEARJET COL model VAL 31 COL cert...
# 66      COL make VAL BELLANCA COL model VAL 14 13 COL ...
# 70      COL make VAL BOEING COL model VAL 737 COL name...
# ...                                                   ...
# 264603  COL make VAL CESSNA COL model VAL 525 COL name...
# 264616  COL make VAL MORANE SAULNIER COL model VAL MS8...
# 264622  COL make VAL AVIAN COL model VAL MAGNUM IX COL...
# 264623  COL make VAL EMBRAER COL model VAL EMB550 COL ...
# 264628  COL make VAL EMBRAER COL model VAL EMB110 COL ...
#
#                                                     right  match  \
# 11      COL mfr VAL AGUSTA COL model VAL A-119 Koala C...      1
# 16      COL mfr VAL PARTENAVIA COL model VAL AP-68TP-3...      1
# 32                   COL mfr VAL LEARJET COL model VAL 31      1
# 66      COL mfr VAL NORTHERN COL model VAL 14 Cruisema...      1
# 70               COL mfr VAL BOEING COL model VAL 737-401      1
# ...                                                   ...    ...
# 264603              COL mfr VAL CESSNA COL model VAL 525C      1
# 264616  COL mfr VAL PZL-OKECIE COL model VAL PZL-111 K...      1
# 264622  COL make VAL AVIAN COL model VAL MAGNUM COL se...      1
# 264623                                  COL code VAL E550      1
# 264628  COL mfr VAL EMBRAER COL model VAL SC-95 Bandei...      1
#
#         match_confidence  gold                left_id  \
# 11              0.999991     1           AGUSTA AW119
# 16              0.999991     1        PARTENAVIA AP68
# 32              0.999985     1             LEARJET 31
# 66              0.999985     1         BELLANCA 14 13
# 70              0.999988     1             BOEING 737
# ...                  ...   ...                    ...
# 264603          0.999899     1             CESSNA 525
# 264616          0.999962     1  MORANE SAULNIER MS894
# 264622          0.999987     1        AVIAN MAGNUM IX
# 264623          0.999986     1         EMBRAER EMB550
# 264628          0.999991     1         EMBRAER EMB110
#
#                            right_id               source
# 11                 A119 A-119 Koala  doc8643_description
# 16       P68T AP-68TP-300 Spartacus  doc8643_description
# 32                          LJ31 31  doc8643_description
# 66             B14A 14 Cruisemaster  doc8643_description
# 70                        B-737-401                  reg
# ...                             ...                  ...
# 264603                  CE-525-525C                  reg
# 264616  RALL PZL-111 Koliber Senior  doc8643_description
# 264622              AVIAN-MAGNUM-IX                  faa
# 264623                         E550         doc8643_code
# 264628       E110 SC-95 Bandeirante  doc8643_description
#
# [28438 rows x 8 columns]

# %%
import re

PAIR_RE = re.compile(r"COL\s+(?P<key>.*?)\s+VAL\s+(?P<val>.*?)(?=\s+COL\s+|$)")

def record_to_kv_list(record: str):
    """Return list like ['make: WACO', 'model: EGC', ...] in original order."""
    s = str(record)
    return [f"{m.group('key').strip()}: {m.group('val').strip()}"
            for m in PAIR_RE.finditer(s)]

# %%
# assuming your dataframe is called matches and has columns "left" and "right"
matches["left_kv"]  = matches["left"].apply(record_to_kv_list)
matches["right_kv"] = matches["right"].apply(record_to_kv_list)
# Out:
# /tmp/ipykernel_103888/3629942744.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches["left_kv"]  = matches["left"].apply(record_to_kv_list)
# /tmp/ipykernel_103888/3629942744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches["right_kv"] = matches["right"].apply(record_to_kv_list)

# %%
matches.head()
# Out:
#                                                  left  \
# 11  COL make VAL AGUSTA COL model VAL AW119 COL na...
# 16  COL make VAL PARTENAVIA COL model VAL AP68 COL...
# 32  COL make VAL LEARJET COL model VAL 31 COL cert...
# 66  COL make VAL BELLANCA COL model VAL 14 13 COL ...
# 70  COL make VAL BOEING COL model VAL 737 COL name...
#
#                                                 right  match  \
# 11  COL mfr VAL AGUSTA COL model VAL A-119 Koala C...      1
# 16  COL mfr VAL PARTENAVIA COL model VAL AP-68TP-3...      1
# 32               COL mfr VAL LEARJET COL model VAL 31      1
# 66  COL mfr VAL NORTHERN COL model VAL 14 Cruisema...      1
# 70           COL mfr VAL BOEING COL model VAL 737-401      1
#
#     match_confidence  gold          left_id                    right_id  \
# 11          0.999991     1     AGUSTA AW119            A119 A-119 Koala
# 16          0.999991     1  PARTENAVIA AP68  P68T AP-68TP-300 Spartacus
# 32          0.999985     1       LEARJET 31                     LJ31 31
# 66          0.999985     1   BELLANCA 14 13        B14A 14 Cruisemaster
# 70          0.999988     1       BOEING 737                   B-737-401
#
#                  source                                            left_kv  \
# 11  doc8643_description  [make: AGUSTA, model: AW119, name: KOALA, cert...
# 16  doc8643_description  [make: PARTENAVIA, model: AP68, name: SPARTACU...
# 32  doc8643_description            [make: LEARJET, model: 31, cert: A10CE]
# 66  doc8643_description  [make: BELLANCA, model: 14 13, name: CRUISAIR ...
# 70                  reg  [make: BOEING, model: 737, name: MAX 8 MAX 9, ...
#
#                                              right_kv
# 11      [mfr: AGUSTA, model: A-119 Koala, code: A119]
# 16    [mfr: PARTENAVIA, model: AP-68TP-300 Spartacus]
# 32                          [mfr: LEARJET, model: 31]
# 66  [mfr: NORTHERN, model: 14 Cruisemaster, code: ...
# 70                      [mfr: BOEING, model: 737-401]

# %%
matches = matches.sort_values("left_id")

# %%
df_agg_cictt = matches.groupby("left_id", as_index=False).agg(count=("left_kv", "count"))

# %%
df_agg_cictt = matches.groupby("left_id", as_index=False).agg(
    left_count=("left_kv", "count"),
    right_kv_distinct=("right_kv", lambda s: s.dropna().apply(tuple).nunique()),
)

# %%
df_joined = matches.merge(
    df_agg_cictt,
    how="left",
    on=["left_id"],
)

# %%
df_joined.head()
# Out:
#                                                 left  \
# 0  COL make VAL AER PEGASO COL model VAL M100 COL...
# 1  COL make VAL AER PEGASO COL model VAL M100 COL...
# 2  COL make VAL AER PEGASO COL model VAL M100 COL...
# 3  COL make VAL AERMACCHI COL model VAL AL60 COL ...
# 4  COL make VAL AERMACCHI COL model VAL AL60 COL ...
#
#                                                right  match  match_confidence  \
# 0        COL mfr VAL AER-PEGASO COL model VAL M-100S      1          0.999955
# 1  COL make VAL AERPEG COL model VAL M100S COL se...      1          0.975039
# 2  COL make VAL AER PEGASO COL model VAL M100 COL...      1          0.999964
# 3             COL mfr VAL MACCHI COL model VAL AL 60      1          0.999988
# 4  COL mfr VAL AERMACCHI COL model VAL AL-60 Load...      1          0.999991
#
#    gold          left_id               right_id               source  \
# 0     1  AER PEGASO M100     AERPEG-M100S-M100S                  reg
# 1     1  AER PEGASO M100     AERPEG-M100S-M100S                  faa
# 2     1  AER PEGASO M100                     25                cictt
# 3     1   AERMACCHI AL60               AL-60-60                  reg
# 4     1   AERMACCHI AL60  LA60 AL-60 Loadmaster  doc8643_description
#
#                                              left_kv  \
# 0  [make: AER PEGASO, model: M100, cert: NOT CERT...
# 1  [make: AER PEGASO, model: M100, cert: NOT CERT...
# 2  [make: AER PEGASO, model: M100, cert: NOT CERT...
# 3  [make: AERMACCHI, model: AL60, name: SANTA MAR...
# 4  [make: AERMACCHI, model: AL60, name: SANTA MAR...
#
#                                             right_kv  left_count  \
# 0                   [mfr: AER-PEGASO, model: M-100S]           3
# 1  [make: AERPEG, model: M100S, series: M100S, ce...           3
# 2  [make: AER PEGASO, model: M100, series: S, cer...           3
# 3                        [mfr: MACCHI, model: AL 60]          23
# 4          [mfr: AERMACCHI, model: AL-60 Loadmaster]          23
#
#    right_kv_distinct
# 0                  3
# 1                  3
# 2                  3
# 3                 23
# 4                 23

# %%
df_joined.to_csv('cictt_agg_repeat_matches.csv', index=False)

# %%
df_joined["right_kv"][0][0]
# Out:
# 'make: AERPEG'
