# %%
import pandas as pd
import json
import re
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
run_name = "union"


# load JSONL
records = []
with open("../aircraft_er_predictions/" + run_name + "_predictions_all.tsv") as f:
    for line in f:
        records.append(json.loads(line))


        # load JSONL
records_test = []
with open("../aircraft_er_predictions/" + run_name + "_predictions_test.tsv") as f:
    for line in f:
        records_test.append(json.loads(line))

# %%
df_all = pd.DataFrame(records)
df_test = pd.DataFrame(records_test)
df_test.head()
# Out:
#                                                 left  \
# 0  COL make VAL CESSNA COL model VAL 337 COL seri...
# 1  COL make VAL CESSNA COL model VAL FR172 COL se...
# 2  COL make VAL CESSNA COL model VAL 310 COL seri...
# 3  COL make VAL CESSNA COL model VAL 560 COL seri...
# 4  COL make VAL CESSNA COL model VAL A150 COL ser...
#
#                                                right  match  match_confidence
# 0             COL make VAL CESSNA COL model VAL 337B      1          0.999653
# 1  COL make VAL NAVION COL model VAL NAVION COL s...      0          0.999937
# 2  COL make VAL WACO COL model VAL GC7 COL series...      0          0.999963
# 3            COL make VAL CESSNA COL model VAL 560XL      0          0.685998
# 4   COL make VAL MORANE-SAULNIER COL model VAL MS760      0          0.999965

# %%
gold_test = pd.read_csv("../data/aircraft_er/" + run_name + "/test.txt", sep="\t", header=None, names=["left", "right", "gold"])

gold_all = pd.read_csv("../data/aircraft_er/" + run_name + "/all_pairs.txt", sep="\t", header=None, names=["left", "right", "gold"])
print(gold_all.head())
# Out:
#                                                 left  \
# 0  COL make VAL BOEING COL model VAL 737 COL seri...
# 1  COL make VAL HILLER COL model VAL H23 COL seri...
# 2  COL make VAL WEATHERLY COL model VAL 201 COL s...
# 3  COL make VAL BELL COL model VAL UH1 COL series...
# 4  COL make VAL PIPER COL model VAL PA18 COL seri...
#
#                                                right  gold
# 0          COL make VAL BOEING COL model VAL 737-2U9     0
# 1  COL make VAL HILLER COL model VAL UH12 COL ser...     1
# 2  COL make VAL IAI LTD COL model VAL GULFSTREAM ...     0
# 3  COL make VAL PRECISION HELICOPTERS LLC COL mod...     0
# 4  COL make VAL CE COL model VAL 172 COL series V...     0

# %%
df_all["gold"] = gold_all["gold"]
df_test["gold"] = gold_test["gold"]

# %%
#Test Data

y_true_test = df_test["gold"]
y_pred_test = df_test["match"]

print("Accuracy:", accuracy_score(y_true_test, y_pred_test))
print("\nClassification report:\n", classification_report(y_true_test, y_pred_test))
print("\nConfusion matrix:\n", confusion_matrix(y_true_test, y_pred_test))



with open("../aircraft_er_predictions/" + run_name + "_metrics_test.txt", "w") as f:
    print("Accuracy:", accuracy_score(y_true_test, y_pred_test), file=f)
    print("\nClassification report:\n", file=f)
    print(classification_report(y_true_test, y_pred_test), file=f)
    print("\nConfusion matrix:\n", file=f)
    print(confusion_matrix(y_true_test, y_pred_test), file=f)
# Out:
# Accuracy: 0.972378516624041
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1363
#            1       0.96      0.95      0.95       592
#
#     accuracy                           0.97      1955
#    macro avg       0.97      0.97      0.97      1955
# weighted avg       0.97      0.97      0.97      1955
#
#
# Confusion matrix:
#  [[1339   24]
#  [  30  562]]

# %%
#All Data

y_true = df_all["gold"]
y_pred = df_all["match"]

print("Accuracy:", accuracy_score(y_true, y_pred))
print("\nClassification report:\n", classification_report(y_true, y_pred))
print("\nConfusion matrix:\n", confusion_matrix(y_true, y_pred))



with open("../aircraft_er_predictions/" + run_name + "_metrics_all.txt", "w") as f:
    print("Accuracy:", accuracy_score(y_true, y_pred), file=f)
    print("\nClassification report:\n", file=f)
    print(classification_report(y_true, y_pred), file=f)
    print("\nConfusion matrix:\n", file=f)
    print(confusion_matrix(y_true, y_pred), file=f)
# Out:
# Accuracy: 0.9890003069681776
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     13628
#            1       0.98      0.98      0.98      5918
#
#     accuracy                           0.99     19546
#    macro avg       0.99      0.99      0.99     19546
# weighted avg       0.99      0.99      0.99     19546
#
#
# Confusion matrix:
#  [[13526   102]
#  [  113  5805]]

# %%
errors = df_test[df_test["gold"] != df_test["match"]]
print(errors[["left","right","gold","match","match_confidence"]].head(20))
# Out:
#                                                   left  \
# 12   COL make VAL GROB COL model VAL G520 COL serie...
# 47   COL make VAL EUROCOPTER COL model VAL EC225 CO...
# 172  COL make VAL SIKORSKY COL model VAL S92 COL se...
# 180  COL make VAL BEAGLE COL model VAL B121 COL ser...
# 248  COL make VAL DOUGLAS COL model VAL DC3C COL se...
# 273  COL make VAL BEAGLE COL model VAL B206 COL ser...
# 361  COL make VAL DE HAVILLAND COL model VAL DHC4 C...
# 367  COL make VAL AIRBUS HELICOPTERS COL model VAL ...
# 400  COL make VAL LOCKHEED COL model VAL PV1 COL se...
# 442  COL make VAL CESSNA COL model VAL O2 COL serie...
# 446  COL make VAL BELL COL model VAL UH1 COL series...
# 448  COL make VAL MCDONNELL DOUGLAS COL model VAL M...
# 486  COL make VAL TAYLORCRAFT COL model VAL BCS12 C...
# 537  COL make VAL BELL COL model VAL UH1 COL series...
# 548  COL make VAL TAYLORCRAFT COL model VAL BF12 CO...
# 564  COL make VAL CASA COL model VAL CN235 COL seri...
# 572  COL make VAL AIRBUS COL model VAL A330 COL ser...
# 578  COL make VAL BOEING COL model VAL 757 COL seri...
# 605  COL make VAL BOEING COL model VAL 707 COL seri...
# 660  COL make VAL EMBRAER COL model VAL EMB120 COL ...
#
#                                                  right  gold  match  \
# 12   COL make VAL BURKHART GROB LUFT-UND COL model ...     0      1
# 47   COL make VAL EUROCOPTER COL model VAL GAZELLE ...     1      0
# 172           COL make VAL SIKORSKY COL model VAL S-92     1      0
# 180  COL make VAL BEAGLE COL model VAL 121 COL seri...     1      0
# 248      COL make VAL DOUGLAS COL model VAL DC3C-S4C4G     1      0
# 273   COL make VAL BEAGLE COL model VAL B.206 SERIES 2     1      0
# 361  COL make VAL DEHAVILLAND COL model VAL CARIBOU...     1      0
# 367  COL make VAL AIRBUS HELICOPTERS DEUTSCHLAND CO...     1      0
# 400  COL make VAL P COL model VAL V1 COL series VAL...     1      0
# 442             COL make VAL CESSNA COL model VAL O-2A     0      1
# 446  COL make VAL NWSTRC COL model VAL UH1H COL ser...     1      0
# 448  COL make VAL MCDONNELL-DOUGLAS COL model VAL D...     0      1
# 486  COL make VAL TAYLORCRAFT COL model VAL BCS12D-...     0      1
# 537  COL make VAL HAWKINS & POWERS AVIATION INC COL...     0      1
# 548       COL make VAL TAYLORCRAFT COL model VAL BF-65     0      1
# 564  COL make VAL CONSTRUCCIONES AERONAUTICAS SA CO...     0      1
# 572         COL make VAL AIRBUS COL model VAL A330-323     0      1
# 578  COL make VAL B COL model VAL 757 COL series VA...     0      1
# 605         COL make VAL BOEING COL model VAL 707-369C     0      1
# 660       COL make VAL EMBRAER COL model VAL EMB-120ER     1      0
#
#      match_confidence
# 12           0.812610
# 47           0.784814
# 172          0.664309
# 180          0.758616
# 248          0.965313
# 273          0.945963
# 361          0.960927
# 367          0.655325
# 400          0.995664
# 442          0.384178
# 446          0.848519
# 448          0.844719
# 486          0.650959
# 537          0.412142
# 548          0.887438
# 564          0.471794
# 572          0.991853
# 578          0.890739
# 605          0.397783
# 660          0.975110

# %%
errors
# Out:
#                                                    left  \
# 12    COL make VAL GROB COL model VAL G520 COL serie...
# 47    COL make VAL EUROCOPTER COL model VAL EC225 CO...
# 172   COL make VAL SIKORSKY COL model VAL S92 COL se...
# 180   COL make VAL BEAGLE COL model VAL B121 COL ser...
# 248   COL make VAL DOUGLAS COL model VAL DC3C COL se...
# 273   COL make VAL BEAGLE COL model VAL B206 COL ser...
# 361   COL make VAL DE HAVILLAND COL model VAL DHC4 C...
# 367   COL make VAL AIRBUS HELICOPTERS COL model VAL ...
# 400   COL make VAL LOCKHEED COL model VAL PV1 COL se...
# 442   COL make VAL CESSNA COL model VAL O2 COL serie...
# 446   COL make VAL BELL COL model VAL UH1 COL series...
# 448   COL make VAL MCDONNELL DOUGLAS COL model VAL M...
# 486   COL make VAL TAYLORCRAFT COL model VAL BCS12 C...
# 537   COL make VAL BELL COL model VAL UH1 COL series...
# 548   COL make VAL TAYLORCRAFT COL model VAL BF12 CO...
# 564   COL make VAL CASA COL model VAL CN235 COL seri...
# 572   COL make VAL AIRBUS COL model VAL A330 COL ser...
# 578   COL make VAL BOEING COL model VAL 757 COL seri...
# 605   COL make VAL BOEING COL model VAL 707 COL seri...
# 660   COL make VAL EMBRAER COL model VAL EMB120 COL ...
# 741   COL make VAL AIR TRACTOR COL model VAL AT602 C...
# 845   COL make VAL BOEING COL model VAL 767 COL seri...
# 940   COL make VAL BEAGLE COL model VAL B206 COL ser...
# 979   COL make VAL REARWIN COL model VAL 190 COL ser...
# 1011  COL make VAL LOCKHEED COL model VAL 382 COL se...
# 1025  COL make VAL AIRBUS COL model VAL A321 COL ser...
# 1034  COL make VAL BOEING COL model VAL 707 COL seri...
# 1067  COL make VAL AERO DIFUSION COL model VAL D1190...
# 1069  COL make VAL BEAGLE COL model VAL B206 COL ser...
# 1146  COL make VAL LAKE COL model VAL LA4 COL series...
# 1167  COL make VAL CONSOLIDATED VULTEE COL model VAL...
# 1225  COL make VAL PIPER COL model VAL PA60 COL seri...
# 1231  COL make VAL BELL COL model VAL UH1 COL series...
# 1240  COL make VAL ROBINSON COL model VAL R22 COL se...
# 1276  COL make VAL BOEING COL model VAL 720 COL seri...
# 1288  COL make VAL EMBRAER COL model VAL EMB120 COL ...
# 1319  COL make VAL CONSOLIDATED VULTEE COL model VAL...
# 1329  COL make VAL MCDONNELL DOUGLAS HELICOPTER COL ...
# 1352  COL make VAL WACO COL model VAL RNF COL series...
# 1355  COL make VAL DOUGLAS COL model VAL R4D COL ser...
# 1368  COL make VAL BAC COL model VAL ONE ELEVEN COL ...
# 1390  COL make VAL SWEARINGEN COL model VAL SA226 CO...
# 1509  COL make VAL AIRBUS HELICOPTERS COL model VAL ...
# 1537  COL make VAL BOEING COL model VAL 727 COL seri...
# 1548  COL make VAL PZL MIELEC COL model VAL M28 COL ...
# 1656  COL make VAL BOMBARDIER COL model VAL BD500 CO...
# 1671  COL make VAL AIRBUS COL model VAL A319 COL ser...
# 1675  COL make VAL CANADAIR COL model VAL CL215 1A10...
# 1683  COL make VAL STEARMAN COL model VAL B75 COL se...
# 1700  COL make VAL SIKORSKY COL model VAL S70 COL se...
# 1807  COL make VAL AEROSPATIALE COL model VAL AS350 ...
# 1808  COL make VAL BEECH COL model VAL 45 COL series...
# 1843  COL make VAL HAWKER SIDDELEY COL model VAL HS1...
# 1899  COL make VAL STEARMAN COL model VAL A75 COL se...
#
#                                                   right  match  \
# 12    COL make VAL BURKHART GROB LUFT-UND COL model ...      1
# 47    COL make VAL EUROCOPTER COL model VAL GAZELLE ...      0
# 172            COL make VAL SIKORSKY COL model VAL S-92      0
# 180   COL make VAL BEAGLE COL model VAL 121 COL seri...      0
# 248       COL make VAL DOUGLAS COL model VAL DC3C-S4C4G      0
# 273    COL make VAL BEAGLE COL model VAL B.206 SERIES 2      0
# 361   COL make VAL DEHAVILLAND COL model VAL CARIBOU...      0
# 367   COL make VAL AIRBUS HELICOPTERS DEUTSCHLAND CO...      0
# 400   COL make VAL P COL model VAL V1 COL series VAL...      0
# 442              COL make VAL CESSNA COL model VAL O-2A      1
# 446   COL make VAL NWSTRC COL model VAL UH1H COL ser...      0
# 448   COL make VAL MCDONNELL-DOUGLAS COL model VAL D...      1
# 486   COL make VAL TAYLORCRAFT COL model VAL BCS12D-...      1
# 537   COL make VAL HAWKINS & POWERS AVIATION INC COL...      1
# 548        COL make VAL TAYLORCRAFT COL model VAL BF-65      1
# 564   COL make VAL CONSTRUCCIONES AERONAUTICAS SA CO...      1
# 572          COL make VAL AIRBUS COL model VAL A330-323      1
# 578   COL make VAL B COL model VAL 757 COL series VA...      1
# 605          COL make VAL BOEING COL model VAL 707-369C      1
# 660        COL make VAL EMBRAER COL model VAL EMB-120ER      0
# 741   COL make VAL AT COL model VAL 301 COL series V...      1
# 845   COL make VAL B COL model VAL 767 COL series VA...      1
# 940   COL make VAL BEAGLE COL model VAL 206 COL seri...      0
# 979   COL make VAL COMWTH COL model VAL 190 COL seri...      0
# 1011  COL make VAL P COL model VAL 38 COL series VAL...      1
# 1025  COL make VAL A COL model VAL 320 COL series VA...      1
# 1034         COL make VAL BOEING COL model VAL 707-330C      1
# 1067  COL make VAL AERODIFUSION  S L COL model VAL J...      0
# 1069   COL make VAL BEAGLE COL model VAL B.206 SERIES 1      0
# 1146              COL make VAL LAKE COL model VAL LA-4A      0
# 1167  COL make VAL PB COL model VAL Y5 COL series VA...      0
# 1225      COL make VAL PIPER COL model VAL AEROSTAR 600      0
# 1231  COL make VAL ARROW FALCON EXPORTERS INC COL mo...      0
# 1240  COL make VAL ROBINSON HELICOPTER COMPANY COL m...      1
# 1276          COL make VAL BOEING COL model VAL 720-022      0
# 1288       COL make VAL EMBRAER COL model VAL EMB-120QC      0
# 1319  COL make VAL CONSOLIDATED VULTEE COL model VAL...      0
# 1329  COL make VAL GULFSTREAM AEROSPACE COL model VA...      1
# 1352  COL make VAL WACO COL model VAL R COL series V...      0
# 1355     COL make VAL DOUGLAS COL model VAL DC-3S/R4D-8      0
# 1368  COL make VAL BRITISH AIRCRAFT CORP COL model V...      1
# 1390   COL make VAL SWEARINGEN COL model VAL SA226-T(B)      0
# 1509  COL make VAL AIRHLD COL model VAL EC135 COL se...      1
# 1537          COL make VAL BOEING COL model VAL 727-29C      0
# 1548  COL make VAL POLSKIE ZAKLADY LOTNICZE SP Z COL...      0
# 1656  COL make VAL BD COL model VAL 700 COL series V...      1
# 1671  COL make VAL A COL model VAL 318 COL series VA...      1
# 1675     COL make VAL CANADAIR COL model VAL CL215 1A10      0
# 1683      COL make VAL BOEING COL model VAL A75N1(PT17)      1
# 1700          COL make VAL SIKORSKY COL model VAL S-76C      1
# 1807  COL make VAL AS COL model VAL 350D COL series ...      0
# 1808               COL make VAL BEECH COL model VAL A45      0
# 1843  COL make VAL BH COL model VAL 125 COL series V...      1
# 1899            COL make VAL BOEING COL model VAL N2S-4      0
#
#       match_confidence  gold
# 12            0.812610     0
# 47            0.784814     1
# 172           0.664309     1
# 180           0.758616     1
# 248           0.965313     1
# 273           0.945963     1
# 361           0.960927     1
# 367           0.655325     1
# 400           0.995664     1
# 442           0.384178     0
# 446           0.848519     1
# 448           0.844719     0
# 486           0.650959     0
# 537           0.412142     0
# 548           0.887438     0
# 564           0.471794     0
# 572           0.991853     0
# 578           0.890739     0
# 605           0.397783     0
# 660           0.975110     1
# 741           0.979270     0
# 845           0.968851     0
# 940           0.803749     1
# 979           0.851711     1
# 1011          0.915151     0
# 1025          0.970682     0
# 1034          0.648597     0
# 1067          0.774631     1
# 1069          0.955147     1
# 1146          0.894806     1
# 1167          0.999807     1
# 1225          0.972476     1
# 1231          0.778614     1
# 1240          0.448062     0
# 1276          0.999413     1
# 1288          0.978273     1
# 1319          0.964363     1
# 1329          0.717641     0
# 1352          0.967912     1
# 1355          0.999425     1
# 1368          0.561401     0
# 1390          0.874747     1
# 1509          0.963804     0
# 1537          0.999734     1
# 1548          0.975572     1
# 1656          0.845070     0
# 1671          0.867791     0
# 1675          0.858874     1
# 1683          0.397078     0
# 1700          0.828161     0
# 1807          0.667673     1
# 1808          0.999753     1
# 1843          0.976348     0
# 1899          0.908446     1

# %%
errors.to_csv("../aircraft_er_predictions/" + run_name + "_errors_review.csv", index=False)

# %%
def parse_record(record: str):
    """Parse Ditto serialized record into a dict of {field: value}."""
    parts = re.split(r"COL |VAL ", record.strip())
    parts = [p for p in parts if p]  # drop empties
    return {parts[i].strip(): parts[i+1].strip() for i in range(0, len(parts), 2)}

parsed = []

for _, row in errors.iterrows():
    left = parse_record(row["left"])
    right = parse_record(row["right"])
    parsed.append({
        "cictt_make": left.get("cictt_make"),
        "make": right.get("make"),
        "cictt_model": left.get("cictt_model"),
        "model": right.get("model"),
        "cictt_series": left.get("cictt_series"),
        "series": right.get("series"),
        "cictt_cert": left.get("cictt_cert"),
        "cert": right.get("cert"),
        "cictt_name": left.get("cictt_name"),
        "name": right.get("name"),
        "predicted": row["match"],
        "confidence": row["match_confidence"],
        "gold": row["gold"]
    })

aligned = pd.DataFrame(parsed)

# %%
aligned.to_csv("../aircraft_er_predictions/" + run_name + "_aligned_errors_review.csv", index=False)
